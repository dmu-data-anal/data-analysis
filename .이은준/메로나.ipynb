# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('1. 거리두기 시작.csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

    
    
    

fig, ax = plt.subplots()
fig.set_size_inches(20,8)

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
ax.set_axisbelow(True)
ax.bar(['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서추구','강남구','송파구','강동구']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red',zorder=1)
ax.grid(axis='y')
ax.set_title("거리두기 시작 전 코로나 상황")
ax.set_xlabel("자치구")
ax.set_ylabel("추가된 인원수")
fig.savefig('1_거리두기 시작.png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('2. 생활방역 전환.csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

    
    
    

fig, ax = plt.subplots()
fig.set_size_inches(20,8)

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
ax.set_axisbelow(True)
ax.bar(['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서추구','강남구','송파구','강동구']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red',zorder=1)
ax.grid(axis='y')
ax.set_title("생활방역 전환 전 코로나 상황")
ax.set_xlabel("자치구")
ax.set_ylabel("추가된 인원수")
fig.savefig('2. 생활방역 전환.png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('3. 수도권 2단계.csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

    
    
    

fig, ax = plt.subplots()
fig.set_size_inches(20,8)

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
ax.set_axisbelow(True)
ax.bar(['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서추구','강남구','송파구','강동구']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red',zorder=1)
ax.grid(axis='y')
ax.set_title("수도권 2단계 전 코로나 상황")
ax.set_xlabel("자치구")
ax.set_ylabel("추가된 인원수")
fig.savefig('3. 수도권 2단계.png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('4. 2.5단계 강화.csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

    
    
    

fig, ax = plt.subplots()
fig.set_size_inches(20,8)

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
ax.set_axisbelow(True)
ax.bar(['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서추구','강남구','송파구','강동구']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red',zorder=1)
ax.grid(axis='y')
ax.set_title("2.5단계 강화 전 코로나 상황")
ax.set_xlabel("자치구")
ax.set_ylabel("추가된 인원수")
fig.savefig('4. 2.5단계 강화.png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('5. 1단계 하향.csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

    
    
    

fig, ax = plt.subplots()
fig.set_size_inches(20,8)

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
ax.set_axisbelow(True)
ax.bar(['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서추구','강남구','송파구','강동구']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red',zorder=1)
ax.grid(axis='y')
ax.set_title("1단계로 하향 전 코로나 상황")
ax.set_xlabel("자치구")
ax.set_ylabel("추가된 인원수")
fig.savefig('5. 1단계 하향.png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('6. 정밀방역으로 세분화.csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

    
    
    

fig, ax = plt.subplots()
fig.set_size_inches(20,8)

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
ax.set_axisbelow(True)
ax.bar(['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서추구','강남구','송파구','강동구']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red',zorder=1)
ax.grid(axis='y')
ax.set_title("정밀방역으로 세분화 전 코로나 상황")
ax.set_xlabel("자치구")
ax.set_ylabel("추가된 인원수")
fig.savefig('6. 정밀방역으로 세분화.png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('7. 2단계 시행.csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

    
    
    

fig, ax = plt.subplots()
fig.set_size_inches(20,8)

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
ax.set_axisbelow(True)
ax.bar(['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서추구','강남구','송파구','강동구']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red',zorder=1)
ax.grid(axis='y')
ax.set_title("2단계 시행 전 코로나 상황")
ax.set_xlabel("자치구")
ax.set_ylabel("추가된 인원수")
fig.savefig('7. 2단계 시행.png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('8. 2.5단계, 조치완화.csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

    
    
    

fig, ax = plt.subplots()
fig.set_size_inches(20,8)

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
ax.set_axisbelow(True)
ax.bar(['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서추구','강남구','송파구','강동구']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red',zorder=1)
ax.grid(axis='y')
ax.set_title("2.5단계, 조치완화 전 코로나 상황")
ax.set_xlabel("자치구")
ax.set_ylabel("추가된 인원수")
fig.savefig('8. 2.5단계, 조치완화.png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('9. 거리두기 개편(1).csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

    
    
    

fig, ax = plt.subplots()
fig.set_size_inches(20,8)

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
ax.set_axisbelow(True)
ax.bar(['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서추구','강남구','송파구','강동구']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red',zorder=1)
ax.grid(axis='y')
ax.set_title("거리두기 개편1 전 코로나 상황")
ax.set_xlabel("자치구")
ax.set_ylabel("추가된 인원수")
fig.savefig('9. 거리두기 개편(1).png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('9. 거리두기 개편(2).csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

    
    
    

fig, ax = plt.subplots()
fig.set_size_inches(20,8)

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
ax.set_axisbelow(True)
ax.bar(['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서추구','강남구','송파구','강동구']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red',zorder=1)
ax.grid(axis='y')
ax.set_title("거리두기 개편2 전 코로나 상황")
ax.set_xlabel("자치구")
ax.set_ylabel("추가된 인원수")
fig.savefig('9. 거리두기 개편(2).png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('10. 거리두기 4단계.csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

    
    
    

fig, ax = plt.subplots()
fig.set_size_inches(20,8)

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
ax.set_axisbelow(True)
ax.bar(['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서추구','강남구','송파구','강동구']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red',zorder=1)
ax.grid(axis='y')
ax.set_title("거리두기 4단계 전 코로나 상황")
ax.set_xlabel("자치구")
ax.set_ylabel("추가된 인원수")
fig.savefig('10. 거리두기 4단계.png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('11. 거리두기 해제(1).csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

    
    
f.close()

fig, ax = plt.subplots()
fig.set_size_inches(20,8)

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
ax.set_axisbelow(True)
ax.bar(['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서추구','강남구','송파구','강동구']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red',zorder=1)
ax.grid(axis='y')
ax.set_title("거리두기 해제 전 8월 코로나 상황")
ax.set_xlabel("자치구")
ax.set_ylabel("추가된 인원수")
fig.savefig('11. 거리두기 해제(1).png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('11. 거리두기 해제(2).csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

    
    
f.close()

fig, ax = plt.subplots()
fig.set_size_inches(20,8)

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
ax.set_axisbelow(True)
ax.bar(['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서추구','강남구','송파구','강동구']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red',zorder=1)
ax.grid(axis='y')
ax.set_title("거리두기 해제 전 9월 코로나 상황")
ax.set_xlabel("자치구")
ax.set_ylabel("추가된 인원수")
fig.savefig('11. 거리두기 해제(2).png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('11. 거리두기 해제(3).csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

    
    
f.close()

fig, ax = plt.subplots()
fig.set_size_inches(20,8)

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
ax.set_axisbelow(True)
ax.bar(['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서추구','강남구','송파구','강동구']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red',zorder=1)
ax.grid(axis='y')
ax.set_title("거리두기 해제 전 10월 코로나 상황")
ax.set_xlabel("자치구")
ax.set_ylabel("추가된 인원수")
fig.savefig('11. 거리두기 해제(3).png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('11. 거리두기 해제(4).csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

    
    
f.close()

fig, ax = plt.subplots()
fig.set_size_inches(20,8)

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
ax.set_axisbelow(True)
ax.bar(['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서추구','강남구','송파구','강동구']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red',zorder=1)
ax.grid(axis='y')
ax.set_title("거리두기 해제 전 11월 코로나 상황")
ax.set_xlabel("자치구")
ax.set_ylabel("추가된 인원수")
fig.savefig('11. 거리두기 해제(4).png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('11. 거리두기 해제(5).csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

    
    
f.close()

fig, ax = plt.subplots()
fig.set_size_inches(20,8)

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
ax.set_axisbelow(True)
ax.bar(['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서추구','강남구','송파구','강동구']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red',zorder=1)
ax.grid(axis='y')
ax.set_title("거리두기 해제 전 12월 코로나 상황")
ax.set_xlabel("자치구")
ax.set_ylabel("추가된 인원수")
fig.savefig('11. 거리두기 해제(5).png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('11. 거리두기 해제(6).csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

    
    
f.close()

fig, ax = plt.subplots()
fig.set_size_inches(20,8)

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
ax.set_axisbelow(True)
ax.bar(['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서추구','강남구','송파구','강동구']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red',zorder=1)
ax.grid(axis='y')
ax.set_title("거리두기 해제 전 1월 코로나 상황")
ax.set_xlabel("자치구")
ax.set_ylabel("추가된 인원수")
fig.savefig('11. 거리두기 해제(6).png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('11. 거리두기 해제(7).csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

    
    
f.close()

fig, ax = plt.subplots()
fig.set_size_inches(20,8)

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
ax.set_axisbelow(True)
ax.bar(['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서추구','강남구','송파구','강동구']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red',zorder=1)
ax.grid(axis='y')
ax.set_title("거리두기 해제 전 2월 코로나 상황")
ax.set_xlabel("자치구")
ax.set_ylabel("추가된 인원수")
fig.savefig('11. 거리두기 해제(7).png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('11. 거리두기 해제(8).csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

    
    
f.close()

fig, ax = plt.subplots()
fig.set_size_inches(20,8)

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
ax.set_axisbelow(True)
ax.bar(['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서추구','강남구','송파구','강동구']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red',zorder=1)
ax.grid(axis='y')
ax.set_title("거리두기 해제 전 3월 코로나 상황")
ax.set_xlabel("자치구")
ax.set_ylabel("추가된 인원수")
fig.savefig('11. 거리두기 해제(8).png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('11. 거리두기 해제(9).csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

    
    
f.close()

fig, ax = plt.subplots()
fig.set_size_inches(20,8)

plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
ax.set_axisbelow(True)
ax.bar(['종로구','중구','용산구','성동구','광진구','동대문구','중랑구','성북구','강북구','도봉구','노원구','은평구','서대문구','마포구','양천구','강서구','구로구','금천구','영등포구','동작구','관악구','서추구','강남구','송파구','강동구']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','도봉구 추가','노원구 추가','은평구 추가','서대문구 추가','마포구 추가','양천구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red',zorder=1)
ax.grid(axis='y')
ax.set_title("거리두기 해제 전 4월 코로나 상황")
ax.set_xlabel("자치구")
ax.set_ylabel("추가된 인원수")
fig.savefig('11. 거리두기 해제(9).png', dpi=100, facecolor='white')
plt.show()
