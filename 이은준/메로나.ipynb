# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('1. 거리두기 시작.csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

plt.figure(figsize=(25,5))
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
plt.bar(
    ['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red'
)
plt.title("거리두기 시작 전 코로나 상황")
plt.xlabel("자치구")
plt.ylabel("추가된 인원수")
plt.savefig('1_거리두기 시작.png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('2. 생활방역 전환.csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

plt.figure(figsize=(25,5))
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
plt.bar(
    ['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red'
)
plt.title("거리두기 시작 전 코로나 상황")
plt.xlabel("자치구")
plt.ylabel("추가된 인원수")
plt.savefig('2_생활방역 전환.png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('3. 수도권 2단계.csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

plt.figure(figsize=(25,5))
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
plt.bar(
    ['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red'
)
plt.title("거리두기 시작 전 코로나 상황")
plt.xlabel("자치구")
plt.ylabel("추가된 인원수")
plt.savefig('3_수도권 2단계.png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('4. 2.5단계 강화.csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

plt.figure(figsize=(25,5))
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
plt.bar(
    ['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red'
)
plt.title("거리두기 시작 전 코로나 상황")
plt.xlabel("자치구")
plt.ylabel("추가된 인원수")
plt.savefig('4_2-5단계 강화.png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('5. 1단계 하향.csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

plt.figure(figsize=(25,5))
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
plt.bar(
    ['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red'
)
plt.title("거리두기 시작 전 코로나 상황")
plt.xlabel("자치구")
plt.ylabel("추가된 인원수")
plt.savefig('5_1단계 하향.png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('6. 정밀방역으로 세분화.csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

plt.figure(figsize=(25,5))
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
plt.bar(
    ['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red'
)
plt.title("거리두기 시작 전 코로나 상황")
plt.xlabel("자치구")
plt.ylabel("추가된 인원수")
plt.savefig('6_정밀방역으로 세분화.png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('7. 2단계 시행.csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

plt.figure(figsize=(25,5))
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
plt.bar(
    ['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red'
)
plt.title("거리두기 시작 전 코로나 상황")
plt.xlabel("자치구")
plt.ylabel("추가된 인원수")
plt.savefig('7_2단계 시행.png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('8. 2.5단계, 조치완화.csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

plt.figure(figsize=(25,5))
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
plt.bar(
    ['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red'
)
plt.title("거리두기 시작 전 코로나 상황")
plt.xlabel("자치구")
plt.ylabel("추가된 인원수")
plt.savefig('8_2-5단계, 조치완화.png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('9. 거리두기 개편.csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

plt.figure(figsize=(25,5))
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
plt.bar(
    ['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red'
)
plt.title("거리두기 시작 전 코로나 상황")
plt.xlabel("자치구")
plt.ylabel("추가된 인원수")
plt.savefig('9_거리두기 개편.png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('10. 거리두기 4단계.csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

plt.figure(figsize=(25,5))
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
plt.bar(
    ['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red'
)
plt.title("거리두기 시작 전 코로나 상황")
plt.xlabel("자치구")
plt.ylabel("추가된 인원수")
plt.savefig('10. 거리두기 4단계.png', dpi=100, facecolor='white')
plt.show()

# %%
import matplotlib.pyplot as plt
import csv
import pandas as pd
import numpy  as np


f = open('11. 거리두기 해제.csv')
data = pd.read_csv(f)


data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()

plt.figure(figsize=(25,5))
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus=False)
plt.bar(
    ['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']
    ,data[['종로구 추가','중구 추가','용산구 추가','성동구 추가','광진구 추가','동대문구 추가','중랑구 추가','성북구 추가','강북구 추가','강서구 추가','구로구 추가','금천구 추가','영등포구 추가','동작구 추가','관악구 추가','서추구 추가','강남구 추가','송파구 추가','강동구 추가']].sum()
    ,color='red'
)
plt.title("거리두기 시작 전 코로나 상황")
plt.xlabel("자치구")
plt.ylabel("추가된 인원수")
plt.savefig('11_거리두기 해제.png', dpi=100, facecolor='white')
plt.show()
